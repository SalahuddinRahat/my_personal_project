# %% [markdown]
# <a href="https://colab.research.google.com/github/SalahuddinRahat/my_personal_project/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from google.colab.patches import cv2_imshow
import cv2

# Upload the image
uploaded = files.upload()

# Replace 'alice.png' with the name of your uploaded file
img = cv2.imread("alice.png", 1)

# Check if the image is loaded correctly
if img is None:
    print("Error: Could not load the image. Please check the file path or re-upload.")
else:
    # Display the image
    cv2_imshow(img)
# Out:
#      <input type="file" id="files-dc197f50-60f1-4321-9a06-efa2529a8695" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc197f50-60f1-4321-9a06-efa2529a8695">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Beginning

# %% [markdown]
# # introduction to python
#
# let's learn python together

# %%
print("hello, world")
# Out:
# hello, world

# %% [markdown]
# ## variables
# variables are like boxes which hold values
# *integer
# *floating point
# *string
# *boolean
# *list
# *dictionaries.
# *set

# %%
age = 23
name = "rahat"
boolean = "false"
cgpa = 3.7
print(age)
print(name)
print(boolean)
print(cgpa)
# Out:
# 23
# rahat
# false
# 3.7

# %%
a = 10
b = 3
addition = a+b
division = a*b
subtraction = a-b
exponent = a**b
division = a/b
integer_division = a//b
modulus = a%b

print("addition", addition)
print("division", division)
print("subtraction", subtraction)
print("modulus", modulus)
print("inyteger division",integer_division)
print("exponent", exponent)
# Out:
# addition 13
# division 3.3333333333333335
# subtraction 7
# modulus 1
# inyteger division 3
# exponent 1000

# %%
first_name = "Salahuddin"
last_name = "Rahat"
full = first_name +" " + last_name
print(full)
print(full*7,sep=" ")
# Out:
# Salahuddin Rahat
# Salahuddin RahatSalahuddin RahatSalahuddin RahatSalahuddin RahatSalahuddin RahatSalahuddin RahatSalahuddin Rahat

# %%
test = True
test2 = False
test3 = a<b
print( not test)
print(test or test2)
print(test3)
# Out:
# False
# True
# False

# %%
print(f"my name is {name}")
print(f"I am {age} years old")
print(f"I want to get cgpa of {cgpa}")
print("My name is {},I am {} years old" .format(name,age))
# Out:
# my name is rahat
# I am 23 years old
# I want to get cgpa of 3.7
# My name is rahat,I am 23 years old

# %% [markdown]
# ### function

# %%
def say_hello(name,age):
  print(f"hello, {name}! you are {age} years old")
say_hello("Rahat",22)
say_hello("parvej", 23)
say_hello("rakib", 24)
# Out:
# hello, Rahat! you are 22 years old
# hello, parvej! you are 23 years old
# hello, rakib! you are 24 years old

# %%
from random import randint
from time import time

MIN = 20
MAX = 50
def game():
    a = randint(MIN,MAX)
    b = randint(MIN,MAX)
    total = a + b
    print("try to sum these number ASAP: ")
    print(f"{a} + {b} = ?")
    display_time = time()
    answer = int(input("my answer: "))
    input_time = time()
    correct = total == answer
    elapsed = input_time - display_time
    print(f"Result: {correct}! Elapsed time is:{elapsed:.4} seconds")

if __name__ == "__main__":
    game()
# Out:
# try to sum these number ASAP:
# 42 + 49 = ?
# my answer: 91
# Result: True! Elapsed time is:7.624 seconds
